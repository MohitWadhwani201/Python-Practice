# %% [markdown]
# ## Pandas DataFrame and Series
#
# pandas is a powerfull data manipulation library in python, widely used for data analytics and data cleaning. It provides two primary data striuctures: Series and DataFrame.
# Series is one dimensional array like object
# Data Frame is a two dimensional , size mutable, and potentially hetrogeneous tabular data structure with labeled axis(rows and columns).
